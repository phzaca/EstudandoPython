# %% [markdown]
# # Anime

# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np

# %% [markdown]
# ## ETL

# %%
dados = pd.read_csv('anime-dataset-2023.csv')

# %%
dados.head()
# Out:
#    anime_id                             Name             English name  \
# 0         1                     Cowboy Bebop             Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2         6                           Trigun                   Trigun
# 3         7               Witch Hunter Robin       Witch Hunter Robin
# 4         8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                          Other name Score  \
# 0                         カウボーイビバップ  8.75
# 1                    カウボーイビバップ 天国の扉  8.38
# 2                             トライガン  8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)  7.25
# 4                            冒険王ビィト  6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
#                                             Synopsis   Type Episodes  \
# 0  Crime is timeless. By the year 2071, humanity ...     TV     26.0
# 1  Another day, another bounty—such is the life o...  Movie      1.0
# 2  Vash the Stampede is the man with a $$60,000,0...     TV     26.0
# 3  Robin Sena is a powerful craft user drafted in...     TV     26.0
# 4  It is the dark century and the people are suff...     TV     52.0
#
#                           Aired  ...         Studios    Source       Duration  \
# 0   Apr 3, 1998 to Apr 24, 1999  ...         Sunrise  Original  24 min per ep
# 1                   Sep 1, 2001  ...           Bones  Original    1 hr 55 min
# 2   Apr 1, 1998 to Sep 30, 1998  ...        Madhouse     Manga  24 min per ep
# 3   Jul 3, 2002 to Dec 25, 2002  ...         Sunrise  Original  25 min per ep
# 4  Sep 30, 2004 to Sep 29, 2005  ...  Toei Animation     Manga  23 min per ep
#
#                            Rating    Rank Popularity Favorites Scored By  \
# 0  R - 17+ (violence & profanity)    41.0         43     78525  914193.0
# 1  R - 17+ (violence & profanity)   189.0        602      1448  206248.0
# 2       PG-13 - Teens 13 or older   328.0        246     15035  356739.0
# 3       PG-13 - Teens 13 or older  2764.0       1795       613   42829.0
# 4                   PG - Children  4240.0       5126        14    6413.0
#
#    Members                                          Image URL
# 0  1771505  https://cdn.myanimelist.net/images/anime/4/196...
# 1   360978  https://cdn.myanimelist.net/images/anime/1439/...
# 2   727252  https://cdn.myanimelist.net/images/anime/7/203...
# 3   111931  https://cdn.myanimelist.net/images/anime/10/19...
# 4    15001  https://cdn.myanimelist.net/images/anime/7/215...
#
# [5 rows x 24 columns]

# %%
dados['Type'] = pd.Categorical(dados['Type'])

# %%
dados['Type']
# Out:
# 0           TV
# 1        Movie
# 2           TV
# 3           TV
# 4           TV
#          ...
# 24900      ONA
# 24901      ONA
# 24902      ONA
# 24903    Music
# 24904    Music
# Name: Type, Length: 24905, dtype: category
# Categories (7, object): ['Movie', 'Music', 'ONA', 'OVA', 'Special', 'TV', 'UNKNOWN']

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24905 entries, 0 to 24904
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   anime_id      24905 non-null  int64
#  1   Name          24905 non-null  object
#  2   English name  24905 non-null  object
#  3   Other name    24905 non-null  object
#  4   Score         24905 non-null  object
#  5   Genres        24905 non-null  object
#  6   Synopsis      24905 non-null  object
#  7   Type          24905 non-null  category
#  8   Episodes      24905 non-null  object
#  9   Aired         24905 non-null  object
#  10  Premiered     24905 non-null  object
#  11  Status        24905 non-null  object
#  12  Producers     24905 non-null  object
#  13  Licensors     24905 non-null  object
#  14  Studios       24905 non-null  object
#  15  Source        24905 non-null  object
#  16  Duration      24905 non-null  object
#  17  Rating        24905 non-null  object
#  18  Rank          24905 non-null  object
#  19  Popularity    24905 non-null  int64
#  20  Favorites     24905 non-null  int64
#  21  Scored By     24905 non-null  object
#  22  Members       24905 non-null  int64
#  23  Image URL     24905 non-null  object
# dtypes: category(1), int64(4), object(19)
# memory usage: 4.4+ MB

# %% [markdown]
# ## Questões

# %% [markdown]
# ### Fáceis

# %% [markdown]
# #### 1. Quantos animes únicos existem na base?

# %%
dados.head()
# Out:
#    anime_id                             Name             English name  \
# 0         1                     Cowboy Bebop             Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2         6                           Trigun                   Trigun
# 3         7               Witch Hunter Robin       Witch Hunter Robin
# 4         8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                          Other name Score  \
# 0                         カウボーイビバップ  8.75
# 1                    カウボーイビバップ 天国の扉  8.38
# 2                             トライガン  8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)  7.25
# 4                            冒険王ビィト  6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
#                                             Synopsis   Type Episodes  \
# 0  Crime is timeless. By the year 2071, humanity ...     TV     26.0
# 1  Another day, another bounty—such is the life o...  Movie      1.0
# 2  Vash the Stampede is the man with a $$60,000,0...     TV     26.0
# 3  Robin Sena is a powerful craft user drafted in...     TV     26.0
# 4  It is the dark century and the people are suff...     TV     52.0
#
#                           Aired  ...         Studios    Source       Duration  \
# 0   Apr 3, 1998 to Apr 24, 1999  ...         Sunrise  Original  24 min per ep
# 1                   Sep 1, 2001  ...           Bones  Original    1 hr 55 min
# 2   Apr 1, 1998 to Sep 30, 1998  ...        Madhouse     Manga  24 min per ep
# 3   Jul 3, 2002 to Dec 25, 2002  ...         Sunrise  Original  25 min per ep
# 4  Sep 30, 2004 to Sep 29, 2005  ...  Toei Animation     Manga  23 min per ep
#
#                            Rating    Rank Popularity Favorites Scored By  \
# 0  R - 17+ (violence & profanity)    41.0         43     78525  914193.0
# 1  R - 17+ (violence & profanity)   189.0        602      1448  206248.0
# 2       PG-13 - Teens 13 or older   328.0        246     15035  356739.0
# 3       PG-13 - Teens 13 or older  2764.0       1795       613   42829.0
# 4                   PG - Children  4240.0       5126        14    6413.0
#
#    Members                                          Image URL
# 0  1771505  https://cdn.myanimelist.net/images/anime/4/196...
# 1   360978  https://cdn.myanimelist.net/images/anime/1439/...
# 2   727252  https://cdn.myanimelist.net/images/anime/7/203...
# 3   111931  https://cdn.myanimelist.net/images/anime/10/19...
# 4    15001  https://cdn.myanimelist.net/images/anime/7/215...
#
# [5 rows x 24 columns]

# %%
dados['Name'].nunique()
# Out:
# 24901

# %% [markdown]
# #### 2. Liste todos os tipos de animes (coluna "Type") disponíveis e indique qual é o mais frequente.

# %%
dados.groupby('Type')['anime_id'].count().reset_index().sort_values('anime_id',ascending=False).reset_index(drop = True)
# Out:
#       Type  anime_id
# 0       TV      7597
# 1    Movie      4381
# 2      OVA      4076
# 3      ONA      3533
# 4    Music      2686
# 5  Special      2558
# 6  UNKNOWN        74

# %% [markdown]
# #### 3. Qual é o anime mais antigo e o mais recente de acordo com a coluna "Aired"?

# %%
anime_data = dados[['Name','Aired']].reset_index(drop=True)
anime_data.head()
# Out:
#                               Name                         Aired
# 0                     Cowboy Bebop   Apr 3, 1998 to Apr 24, 1999
# 1  Cowboy Bebop: Tengoku no Tobira                   Sep 1, 2001
# 2                           Trigun   Apr 1, 1998 to Sep 30, 1998
# 3               Witch Hunter Robin   Jul 3, 2002 to Dec 25, 2002
# 4                   Bouken Ou Beet  Sep 30, 2004 to Sep 29, 2005

# %%
anime_data[['start','end']] = anime_data['Aired'].str.split('to',expand = True)
anime_data.head()
# Out:
#                               Name                         Aired  \
# 0                     Cowboy Bebop   Apr 3, 1998 to Apr 24, 1999
# 1  Cowboy Bebop: Tengoku no Tobira                   Sep 1, 2001
# 2                           Trigun   Apr 1, 1998 to Sep 30, 1998
# 3               Witch Hunter Robin   Jul 3, 2002 to Dec 25, 2002
# 4                   Bouken Ou Beet  Sep 30, 2004 to Sep 29, 2005
#
#            start            end
# 0   Apr 3, 1998    Apr 24, 1999
# 1    Sep 1, 2001           None
# 2   Apr 1, 1998    Sep 30, 1998
# 3   Jul 3, 2002    Dec 25, 2002
# 4  Sep 30, 2004    Sep 29, 2005

# %%
anime_data.drop(columns=['Aired'],inplace=True)
anime_data.head()
# Out:
#                               Name          start            end
# 0                     Cowboy Bebop   Apr 3, 1998    Apr 24, 1999
# 1  Cowboy Bebop: Tengoku no Tobira    Sep 1, 2001           None
# 2                           Trigun   Apr 1, 1998    Sep 30, 1998
# 3               Witch Hunter Robin   Jul 3, 2002    Dec 25, 2002
# 4                   Bouken Ou Beet  Sep 30, 2004    Sep 29, 2005

# %%
anime_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24905 entries, 0 to 24904
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    24905 non-null  object
#  1   start   24905 non-null  object
#  2   end     11655 non-null  object
# dtypes: object(3)
# memory usage: 583.8+ KB

# %%
anime_data['start'] = anime_data['start'].str.replace(r'\s+', ' ', regex=True)
anime_data['start'] = anime_data['start'].str.replace(r'\s+', ' ', regex=True).str.strip()
anime_data['start'] = pd.to_datetime(anime_data['start'], errors='coerce')

# %%
anime_data['end'] = anime_data['end'].str.replace(r'\s+', ' ', regex=True)
anime_data['end'] = anime_data['end'].str.replace(r'\s+', ' ', regex=True).str.strip()
anime_data['end'] = pd.to_datetime(anime_data['end'], errors='coerce')

# %%
anime_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24905 entries, 0 to 24904
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    24905 non-null  object
#  1   start   20090 non-null  datetime64[ns]
#  2   end     9337 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), object(1)
# memory usage: 583.8+ KB

# %%
anime_data.head()
# Out:
#                               Name      start        end
# 0                     Cowboy Bebop 1998-04-03 1999-04-24
# 1  Cowboy Bebop: Tengoku no Tobira 2001-09-01        NaT
# 2                           Trigun 1998-04-01 1998-09-30
# 3               Witch Hunter Robin 2002-07-03 2002-12-25
# 4                   Bouken Ou Beet 2004-09-30 2005-09-29

# %%
anime_data = anime_data.dropna(subset=['start'])
anime_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20090 entries, 0 to 24904
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    20090 non-null  object
#  1   start   20090 non-null  datetime64[ns]
#  2   end     9317 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), object(1)
# memory usage: 627.8+ KB

# %%
anime_data.sort_values('start',ascending=False).iloc[0]
# Out:
# Name     Spy x Family Movie: Code: White
# start                2023-12-22 00:00:00
# end                                  NaT
# Name: 23668, dtype: object

# %%
print('O anime mais antigo é ', anime_data.sort_values('start',ascending=False)['Name'].iloc[-1],
      ', que começou em ',anime_data.sort_values('start',ascending=False)['start'].iloc[-1].strftime('%Y-%m-%d'))

print('O anime mais novo é ', anime_data.sort_values('start',ascending=False)['Name'].iloc[0],
      ', que começou em ',anime_data.sort_values('start',ascending=False)['start'].iloc[0].strftime('%Y-%m-%d'))
# Out:
# O anime mais antigo é  Chamebou Shin Gachou: Nomi Fuufu Shikaeshi no Maki , que começou em  1917-04-28
# O anime mais novo é  Spy x Family Movie: Code: White , que começou em  2023-12-22

# %% [markdown]
# #### 4. Há valores ausentes (NaN ou vazios) em alguma coluna? Em quais e quantos em cada uma?

# %%
dados.isna().sum()
# Out:
# anime_id        0
# Name            0
# English name    0
# Other name      0
# Score           0
# Genres          0
# Synopsis        0
# Type            0
# Episodes        0
# Aired           0
# Premiered       0
# Status          0
# Producers       0
# Licensors       0
# Studios         0
# Source          0
# Duration        0
# Rating          0
# Rank            0
# Popularity      0
# Favorites       0
# Scored By       0
# Members         0
# Image URL       0
# dtype: int64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24905 entries, 0 to 24904
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   anime_id      24905 non-null  int64
#  1   Name          24905 non-null  object
#  2   English name  24905 non-null  object
#  3   Other name    24905 non-null  object
#  4   Score         24905 non-null  object
#  5   Genres        24905 non-null  object
#  6   Synopsis      24905 non-null  object
#  7   Type          24905 non-null  object
#  8   Episodes      24905 non-null  object
#  9   Aired         24905 non-null  object
#  10  Premiered     24905 non-null  object
#  11  Status        24905 non-null  object
#  12  Producers     24905 non-null  object
#  13  Licensors     24905 non-null  object
#  14  Studios       24905 non-null  object
#  15  Source        24905 non-null  object
#  16  Duration      24905 non-null  object
#  17  Rating        24905 non-null  object
#  18  Rank          24905 non-null  object
#  19  Popularity    24905 non-null  int64
#  20  Favorites     24905 non-null  int64
#  21  Scored By     24905 non-null  object
#  22  Members       24905 non-null  int64
#  23  Image URL     24905 non-null  object
# dtypes: int64(4), object(20)
# memory usage: 4.6+ MB

# %% [markdown]
# #### 5. Qual o maior e o menor valor nas colunas “Score” e “Rank”?

# %%
score_rank = dados[['Name','Score','Rank']]
score_rank.head()
# Out:
#                               Name Score    Rank
# 0                     Cowboy Bebop  8.75    41.0
# 1  Cowboy Bebop: Tengoku no Tobira  8.38   189.0
# 2                           Trigun  8.22   328.0
# 3               Witch Hunter Robin  7.25  2764.0
# 4                   Bouken Ou Beet  6.94  4240.0

# %%
score_rank['Score'] = pd.to_numeric(score_rank['Score'], errors='coerce')
score_rank['Score'] = score_rank['Score'].fillna(0)
score_rank['Rank'] = pd.to_numeric(score_rank['Rank'], errors='coerce')
score_rank['Rank'] = score_rank['Rank'].fillna(0)
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_17888\977216661.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score_rank['Score'] = pd.to_numeric(score_rank['Score'], errors='coerce')
# C:\Users\pedro\AppData\Local\Temp\ipykernel_17888\977216661.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score_rank['Score'] = score_rank['Score'].fillna(0)
# C:\Users\pedro\AppData\Local\Temp\ipykernel_17888\977216661.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score_rank['Rank'] = pd.to_numeric(score_rank['Rank'], errors='coerce')
# C:\Users\pedro\AppData\Local\Temp\ipykernel_17888\977216661.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score_rank['Rank'] = score_rank['Rank'].fillna(0)

# %%
score_rank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24905 entries, 0 to 24904
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    24905 non-null  object
#  1   Score   24905 non-null  float64
#  2   Rank    24905 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 583.8+ KB

# %%
score_rank.loc[score_rank['Score']!= 0].reset_index(drop=True).sort_values('Score')
# Out:
#                                      Name  Score     Rank
# 2913         Tenkuu Danzai Skelter+Heaven   1.85  12701.0
# 6682                   Utsu Musume Sayuri   1.98  12699.0
# 4161                         Tsui no Sora   2.22      0.0
# 387                       Hametsu no Mars   2.22  12698.0
# 9614                             Kokuhaku   2.30  12697.0
# ...                                   ...    ...      ...
# 12412  Shingeki no Kyojin Season 3 Part 2   9.05      6.0
# 8816                             Gintama°   9.06      4.0
# 5541                          Steins;Gate   9.07      3.0
# 13656           Bleach: Sennen Kessen-hen   9.07      2.0
# 3933     Fullmetal Alchemist: Brotherhood   9.10      1.0
#
# [15692 rows x 3 columns]

# %%
print('O anime de menor score é',
      score_rank.loc[score_rank['Score']!= 0].reset_index(drop=True).sort_values('Score').iloc[0]['Name'],
      ', o valor score era',
      score_rank.loc[score_rank['Score']!= 0].reset_index(drop=True).sort_values('Score').iloc[0]['Score'])
# Out:
# O anime de menor score é Tenkuu Danzai Skelter+Heaven , o valor score era 1.85

# %%
print('O anime de maior score é',
      score_rank.loc[score_rank['Score']!= 0].reset_index(drop=True).sort_values('Score').iloc[-1]['Name'],
      ', o valor score era',
      score_rank.loc[score_rank['Score']!= 0].reset_index(drop=True).sort_values('Score').iloc[-1]['Score'])
# Out:
# O anime de maior score é Fullmetal Alchemist: Brotherhood , o valor score era 9.1

# %%
print('O anime de menor rank é',
      score_rank.loc[score_rank['Rank']!= 0].reset_index(drop=True).sort_values('Rank').iloc[0]['Name'],
      ', o valor rank era',
      score_rank.loc[score_rank['Rank']!= 0].reset_index(drop=True).sort_values('Rank').iloc[0]['Rank'])
# Out:
# O anime de menor rank é Fullmetal Alchemist: Brotherhood , o valor rank era 1.0

# %%
print('O anime de menor rank é',
      score_rank.loc[score_rank['Rank']!= 0].reset_index(drop=True).sort_values('Rank').iloc[-1]['Name'],
      ', o valor rank era',
      score_rank.loc[score_rank['Rank']!= 0].reset_index(drop=True).sort_values('Rank').iloc[-1]['Rank'])
# Out:
# O anime de menor rank é Super Titans 15 , o valor rank era 20104.0

# %% [markdown]
# ### Intermediárias

# %% [markdown]
# #### 6. Quais são os 10 estúdios (“Studios”) com mais animes cadastrados?

# %%
dados.groupby('Studios')['anime_id'].count().reset_index().sort_values('anime_id',ascending=False).head(11)
# Out:
#                              Studios  anime_id
# 1419                         UNKNOWN     10526
# 1351                  Toei Animation       834
# 1247                         Sunrise       532
# 519                        J.C.Staff       385
# 1032  Shanghai Animation Film Studio       335
# 648                         Madhouse       333
# 1282               TMS Entertainment       317
# 1129                     Studio Deen       290
# 898                   Production I.G       269
# 860                          Pierrot       264
# 763                              OLM       246

# %% [markdown]
# #### 7. Liste todos os gêneros (“Genres”) únicos — lembrando de tratar múltiplos gêneros separados por vírgula.

# %%
generos = dados['Genres']
generos.head()
# Out:
# 0           Action, Award Winning, Sci-Fi
# 1                          Action, Sci-Fi
# 2               Action, Adventure, Sci-Fi
# 3    Action, Drama, Mystery, Supernatural
# 4        Adventure, Fantasy, Supernatural
# Name: Genres, dtype: object

# %%
generos = generos.str.split(',')
generos = generos.explode('Genres')
generos
# Out:
# 0                Action
# 1         Award Winning
# 2                Sci-Fi
# 3                Action
# 4                Sci-Fi
#               ...
# 43385         Adventure
# 43386           Fantasy
# 43387            Sci-Fi
# 43388           UNKNOWN
# 43389           UNKNOWN
# Name: Genres, Length: 43390, dtype: object

# %%
generos.unique()
# Out:
# array(['Action', ' Award Winning', ' Sci-Fi', ' Adventure', ' Drama',
#        ' Mystery', ' Supernatural', 'Adventure', ' Fantasy', 'Sports',
#        'Comedy', ' Romance', ' Slice of Life', ' Sports', 'Drama',
#        ' Suspense', ' Comedy', ' Ecchi', ' Gourmet', ' Avant Garde',
#        'Avant Garde', ' Horror', 'Award Winning', ' Girls Love', 'Sci-Fi',
#        ' Boys Love', 'Mystery', ' Hentai', 'Hentai', 'Horror',
#        'Boys Love', 'Fantasy', 'Ecchi', 'Slice of Life', 'UNKNOWN',
#        'Romance', 'Suspense', ' Erotica', 'Supernatural', 'Girls Love',
#        'Erotica', 'Gourmet'], dtype=object)

# %% [markdown]
# #### 8. Conte quantos animes têm nota (“Score”) acima de 8,5.

# %%
score_rank.loc[score_rank['Score']>8.5]['Name'].count()
# Out:
# np.int64(123)

# %% [markdown]
# #### 9. Entre os animes do tipo “Movie”, qual tem mais membros (“Members”)?

# %%
dados[dados['Type']=='Movie'][['Name','Members']].sort_values('Members',ascending=False).head(1)
# Out:
#                  Name  Members
# 11256  Kimi no Na wa.  2597495

# %% [markdown]
# #### 10. Qual ano teve mais lançamentos de animes (usando “Aired”)?

# %%
anime_data = dados[['Name','Aired']]
anime_data.head()
# Out:
#                               Name                         Aired
# 0                     Cowboy Bebop   Apr 3, 1998 to Apr 24, 1999
# 1  Cowboy Bebop: Tengoku no Tobira                   Sep 1, 2001
# 2                           Trigun   Apr 1, 1998 to Sep 30, 1998
# 3               Witch Hunter Robin   Jul 3, 2002 to Dec 25, 2002
# 4                   Bouken Ou Beet  Sep 30, 2004 to Sep 29, 2005

# %%
anime_data[['start','end']] = anime_data['Aired'].str.split('to',expand=True)
anime_data.drop(columns='Aired',inplace=True)
anime_data
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_17888\488424090.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_data[['start','end']] = anime_data['Aired'].str.split('to',expand=True)
# C:\Users\pedro\AppData\Local\Temp\ipykernel_17888\488424090.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_data[['start','end']] = anime_data['Aired'].str.split('to',expand=True)
# C:\Users\pedro\AppData\Local\Temp\ipykernel_17888\488424090.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_data.drop(columns='Aired',inplace=True)
#                                   Name          start            end
# 0                         Cowboy Bebop   Apr 3, 1998    Apr 24, 1999
# 1      Cowboy Bebop: Tengoku no Tobira    Sep 1, 2001           None
# 2                               Trigun   Apr 1, 1998    Sep 30, 1998
# 3                   Witch Hunter Robin   Jul 3, 2002    Dec 25, 2002
# 4                       Bouken Ou Beet  Sep 30, 2004    Sep 29, 2005
# ...                                ...            ...            ...
# 24900                      Wu Nao Monu   Jul 4, 2023               ?
# 24901              Bu Xing Si: Yuan Qi  Jul 27, 2023               ?
# 24902                      Di Yi Xulie  Jul 19, 2023               ?
# 24903         Bokura no Saishuu Sensou   Apr 23, 2022           None
# 24904                   Shijuuku Nichi    Sep 5, 2022           None
#
# [24905 rows x 3 columns]

# %%
anime_data['start'] = anime_data['start'].str.replace(r'\s+', ' ', regex=True).str.strip()
anime_data['start'] = pd.to_datetime(anime_data['start'], errors='coerce')
anime_data['end'] = anime_data['end'].str.replace(r'\s+', ' ', regex=True).str.strip()
anime_data['end'] = pd.to_datetime(anime_data['end'], errors='coerce')
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_17888\285613628.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_data['start'] = anime_data['start'].str.replace(r'\s+', ' ', regex=True).str.strip()
# C:\Users\pedro\AppData\Local\Temp\ipykernel_17888\285613628.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_data['start'] = pd.to_datetime(anime_data['start'], errors='coerce')
# C:\Users\pedro\AppData\Local\Temp\ipykernel_17888\285613628.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_data['end'] = anime_data['end'].str.replace(r'\s+', ' ', regex=True).str.strip()
# C:\Users\pedro\AppData\Local\Temp\ipykernel_17888\285613628.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_data['end'] = pd.to_datetime(anime_data['end'], errors='coerce')

# %%
anime_data
# Out:
#                                   Name      start        end
# 0                         Cowboy Bebop 1998-04-03 1999-04-24
# 1      Cowboy Bebop: Tengoku no Tobira 2001-09-01        NaT
# 2                               Trigun 1998-04-01 1998-09-30
# 3                   Witch Hunter Robin 2002-07-03 2002-12-25
# 4                       Bouken Ou Beet 2004-09-30 2005-09-29
# ...                                ...        ...        ...
# 24900                      Wu Nao Monu 2023-07-04        NaT
# 24901              Bu Xing Si: Yuan Qi 2023-07-27        NaT
# 24902                      Di Yi Xulie 2023-07-19        NaT
# 24903         Bokura no Saishuu Sensou 2022-04-23        NaT
# 24904                   Shijuuku Nichi 2022-09-05        NaT
#
# [24905 rows x 3 columns]

# %%
anime_data['start'].dt.year.astype('Int64').reset_index().groupby('start').count().sort_values('index',ascending=False).head(1)
# Out:
#        index
# start
# 2017    1113

# %% [markdown]
# ### Avançadas

# %% [markdown]
# #### 11. Exploda a coluna “Genres” em linhas e encontre o top 10 de gêneros mais comuns.

# %%
generos = dados['Genres']
generos
# Out:
# 0               Action, Award Winning, Sci-Fi
# 1                              Action, Sci-Fi
# 2                   Action, Adventure, Sci-Fi
# 3        Action, Drama, Mystery, Supernatural
# 4            Adventure, Fantasy, Supernatural
#                          ...
# 24900          Comedy, Fantasy, Slice of Life
# 24901              Action, Adventure, Fantasy
# 24902      Action, Adventure, Fantasy, Sci-Fi
# 24903                                 UNKNOWN
# 24904                                 UNKNOWN
# Name: Genres, Length: 24905, dtype: object

# %%
generos=generos.str.split(',')
generos
# Out:
# 0                [Action,  Award Winning,  Sci-Fi]
# 1                                [Action,  Sci-Fi]
# 2                    [Action,  Adventure,  Sci-Fi]
# 3        [Action,  Drama,  Mystery,  Supernatural]
# 4             [Adventure,  Fantasy,  Supernatural]
#                            ...
# 24900           [Comedy,  Fantasy,  Slice of Life]
# 24901               [Action,  Adventure,  Fantasy]
# 24902      [Action,  Adventure,  Fantasy,  Sci-Fi]
# 24903                                    [UNKNOWN]
# 24904                                    [UNKNOWN]
# Name: Genres, Length: 24905, dtype: object

# %%
generos=generos.explode('Genres')
generos
# Out:
# 0                Action
# 1         Award Winning
# 2                Sci-Fi
# 3                Action
# 4                Sci-Fi
#               ...
# 43385         Adventure
# 43386           Fantasy
# 43387            Sci-Fi
# 43388           UNKNOWN
# 43389           UNKNOWN
# Name: Genres, Length: 43390, dtype: object

# %%
generos.reset_index().groupby('Genres')['index'].count().reset_index().sort_values('index',ascending=False).head(11)
# Out:
#         Genres  index
# 25      Comedy   5140
# 41     UNKNOWN   4929
# 20      Action   4730
# 8      Fantasy   3623
# 15      Sci-Fi   2672
# 21   Adventure   2269
# 4       Comedy   2002
# 14     Romance   1756
# 29     Fantasy   1683
# 0    Adventure   1573
# 26       Drama   1470

# %% [markdown]
# #### 12. Quais animes aparecem simultaneamente em mais de um idioma diferente na coluna “English name”?

# %%
dados['English name']
# Out:
# 0                   Cowboy Bebop
# 1        Cowboy Bebop: The Movie
# 2                         Trigun
# 3             Witch Hunter Robin
# 4         Beet the Vandel Buster
#                   ...
# 24900                    UNKNOWN
# 24901                Blader Soul
# 24902            The First Order
# 24903                    UNKNOWN
# 24904                    UNKNOWN
# Name: English name, Length: 24905, dtype: object

# %%
dados['Other name']
# Out:
# 0                               カウボーイビバップ
# 1                          カウボーイビバップ 天国の扉
# 2                                   トライガン
# 3        Witch Hunter ROBIN (ウイッチハンターロビン)
# 4                                  冒険王ビィト
#                        ...
# 24900                                无脑魔女
# 24901                              捕星司·源起
# 24902                                第一序列
# 24903                             僕らの最終戦争
# 24904                                四十九日
# Name: Other name, Length: 24905, dtype: object

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24905 entries, 0 to 24904
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   anime_id      24905 non-null  int64
#  1   Name          24905 non-null  object
#  2   English name  24905 non-null  object
#  3   Other name    24905 non-null  object
#  4   Score         24905 non-null  object
#  5   Genres        24905 non-null  object
#  6   Synopsis      24905 non-null  object
#  7   Type          24905 non-null  object
#  8   Episodes      24905 non-null  object
#  9   Aired         24905 non-null  object
#  10  Premiered     24905 non-null  object
#  11  Status        24905 non-null  object
#  12  Producers     24905 non-null  object
#  13  Licensors     24905 non-null  object
#  14  Studios       24905 non-null  object
#  15  Source        24905 non-null  object
#  16  Duration      24905 non-null  object
#  17  Rating        24905 non-null  object
#  18  Rank          24905 non-null  object
#  19  Popularity    24905 non-null  int64
#  20  Favorites     24905 non-null  int64
#  21  Scored By     24905 non-null  object
#  22  Members       24905 non-null  int64
#  23  Image URL     24905 non-null  object
# dtypes: int64(4), object(20)
# memory usage: 4.6+ MB

# %%
dados.loc[(dados['English name']== dados['Name']) | (dados['English name']== dados['Other name'])]
# Out:
#        anime_id                  Name          English name  \
# 0             1          Cowboy Bebop          Cowboy Bebop
# 2             6                Trigun                Trigun
# 3             7    Witch Hunter Robin    Witch Hunter Robin
# 9            19               Monster               Monster
# 10           20                Naruto                Naruto
# ...         ...                   ...                   ...
# 24856     55676                  Fins                  Fins
# 24857     55677             DEATHNOTE             DEATHNOTE
# 24859     55680      Kanojo mo kanojo               UNKNOWN
# 24885     55716           Mechronicle           Mechronicle
# 24887     54693  Observing Elena Evoy  Observing Elena Evoy
#
#                              Other name    Score  \
# 0                             カウボーイビバップ     8.75
# 2                                 トライガン     8.22
# 3      Witch Hunter ROBIN (ウイッチハンターロビン)     7.25
# 9                                 モンスター     8.87
# 10                                  ナルト     7.99
# ...                                 ...      ...
# 24856                              Fins     6.45
# 24857                           UNKNOWN  UNKNOWN
# 24859                           UNKNOWN  UNKNOWN
# 24885                       Mechronicle  UNKNOWN
# 24887                     일레나 에보이 관찰 일지  UNKNOWN
#
#                                      Genres  \
# 0             Action, Award Winning, Sci-Fi
# 2                 Action, Adventure, Sci-Fi
# 3      Action, Drama, Mystery, Supernatural
# 9                  Drama, Mystery, Suspense
# 10               Action, Adventure, Fantasy
# ...                                     ...
# 24856                               UNKNOWN
# 24857                               UNKNOWN
# 24859                               UNKNOWN
# 24885                               UNKNOWN
# 24887                      Fantasy, Romance
#
#                                                 Synopsis     Type Episodes  \
# 0      Crime is timeless. By the year 2071, humanity ...       TV     26.0
# 2      Vash the Stampede is the man with a $$60,000,0...       TV     26.0
# 3      Robin Sena is a powerful craft user drafted in...       TV     26.0
# 9      Dr. Kenzou Tenma, an elite neurosurgeon recent...       TV     74.0
# 10     Moments prior to Naruto Uzumaki's birth, a hug...       TV    220.0
# ...                                                  ...      ...      ...
# 24856  Music video for the song Fins by Tsunomaki Wat...    Music      1.0
# 24857           No description available for this anime.  UNKNOWN     37.0
# 24859           No description available for this anime.  UNKNOWN     12.0
# 24885  Set in a mechanical world, Mechronicle tells t...  UNKNOWN  UNKNOWN
# 24887  "If you're not my rival, why do I feel this wa...      ONA     12.0
#
#                              Aired  ...   Studios    Source       Duration  \
# 0      Apr 3, 1998 to Apr 24, 1999  ...   Sunrise  Original  24 min per ep
# 2      Apr 1, 1998 to Sep 30, 1998  ...  Madhouse     Manga  24 min per ep
# 3      Jul 3, 2002 to Dec 25, 2002  ...   Sunrise  Original  25 min per ep
# 9      Apr 7, 2004 to Sep 28, 2005  ...  Madhouse     Manga  24 min per ep
# 10      Oct 3, 2002 to Feb 8, 2007  ...   Pierrot     Manga  23 min per ep
# ...                            ...  ...       ...       ...            ...
# 24856                  Jun 6, 2023  ...   UNKNOWN  Original          4 min
# 24857                Not available  ...   UNKNOWN   Unknown        Unknown
# 24859                Not available  ...   UNKNOWN   Unknown        Unknown
# 24885                Not available  ...   UNKNOWN  Original        Unknown
# 24887            Mar 10, 2023 to ?  ...   UNKNOWN     Novel   5 min per ep
#
#                                Rating     Rank Popularity Favorites  \
# 0      R - 17+ (violence & profanity)     41.0         43     78525
# 2           PG-13 - Teens 13 or older    328.0        246     15035
# 3           PG-13 - Teens 13 or older   2764.0       1795       613
# 9                    R+ - Mild Nudity     26.0        142     47235
# 10          PG-13 - Teens 13 or older    599.0          8     76343
# ...                               ...      ...        ...       ...
# 24856                    G - All Ages  UNKNOWN      14842         2
# 24857       PG-13 - Teens 13 or older      0.0          0         0
# 24859                         UNKNOWN      0.0          0         0
# 24885                         UNKNOWN      0.0          0         0
# 24887       PG-13 - Teens 13 or older      0.0          0         0
#
#        Scored By  Members                                          Image URL
# 0       914193.0  1771505  https://cdn.myanimelist.net/images/anime/4/196...
# 2       356739.0   727252  https://cdn.myanimelist.net/images/anime/7/203...
# 3        42829.0   111931  https://cdn.myanimelist.net/images/anime/10/19...
# 9       368569.0  1013100  https://cdn.myanimelist.net/images/anime/10/18...
# 10     1883772.0  2717330  https://cdn.myanimelist.net/images/anime/13/17...
# ...          ...      ...                                                ...
# 24856      194.0      512  https://cdn.myanimelist.net/images/anime/1747/...
# 24857    UNKNOWN        0  https://cdn.myanimelist.net/img/sp/icon/apple-...
# 24859    UNKNOWN        0  https://cdn.myanimelist.net/img/sp/icon/apple-...
# 24885    UNKNOWN        0  https://cdn.myanimelist.net/images/anime/1074/...
# 24887    UNKNOWN        0  https://cdn.myanimelist.net/images/anime/1526/...
#
# [1965 rows x 24 columns]

# %% [markdown]
# #### 13. Qual produtor (“Producers”) aparece em mais animes?

# %%
produtoras = dados['Producers']
produtoras = produtoras.str.split(',')
produtoras
# Out:
# 0                                          [Bandai Visual]
# 1                                [Sunrise,  Bandai Visual]
# 2                                   [Victor Entertainment]
# 3        [Bandai Visual,  Dentsu,  Victor Entertainment...
# 4                                      [TV Tokyo,  Dentsu]
#                                ...
# 24900                                            [UNKNOWN]
# 24901                                            [UNKNOWN]
# 24902                                            [UNKNOWN]
# 24903                                            [UNKNOWN]
# 24904                                            [UNKNOWN]
# Name: Producers, Length: 24905, dtype: object

# %%
produtoras = produtoras.explode('Producers')
produtoras
# Out:
# 0               Bandai Visual
# 1                     Sunrise
# 2               Bandai Visual
# 3        Victor Entertainment
# 4               Bandai Visual
#                  ...
# 38257                 UNKNOWN
# 38258                 UNKNOWN
# 38259                 UNKNOWN
# 38260                 UNKNOWN
# 38261                 UNKNOWN
# Name: Producers, Length: 38262, dtype: object

# %%
produtoras.reset_index().groupby('Producers')['index'].count().reset_index().sort_values('index',ascending=False)
# Out:
#           Producers  index
# 2027        UNKNOWN  13350
# 1681            NHK    797
# 1955       TV Tokyo    554
# 1245        Aniplex    530
# 1291  Bandai Visual    390
# ...             ...    ...
# 1306        Bitgang      1
# 1331            CMI      1
# 1330      CMC MEDIA      1
# 1323            C2C      1
# 1321  Byakuya Shobo      1
#
# [2111 rows x 2 columns]

# %% [markdown]
# #### 14. Existe algum anime com nota (“Score”) maior que 9 e menos de 10 episódios? Liste-os.

# %%
score = dados[['Name','Score','Episodes']]
score['Score'] = pd.to_numeric(score['Score'],errors='coerce')
score['Episodes'] = pd.to_numeric(score['Episodes'],errors='coerce')
dados['Episodes'] = dados['Episodes'].fillna(0)
dados['Score'] = dados['Score'].fillna(0)
score.head()
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_11044\3526318560.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score['Score'] = pd.to_numeric(score['Score'],errors='coerce')
# C:\Users\pedro\AppData\Local\Temp\ipykernel_11044\3526318560.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score['Episodes'] = pd.to_numeric(score['Episodes'],errors='coerce')
#                               Name  Score  Episodes
# 0                     Cowboy Bebop   8.75      26.0
# 1  Cowboy Bebop: Tengoku no Tobira   8.38       1.0
# 2                           Trigun   8.22      26.0
# 3               Witch Hunter Robin   7.25      26.0
# 4                   Bouken Ou Beet   6.94      52.0

# %%
score.loc[(score['Score']>9) & (score['Episodes']<10)]
# Out:
#                                                     Name  Score  Episodes
# 15525                                 Gintama: The Final   9.04       1.0
# 22348  Shingeki no Kyojin: The Final Season - Kankets...   9.05       2.0

# %% [markdown]
# #### 15. Monte um gráfico de barras com o número de animes produzidos por década.

# %%
anime_data = dados[['Name','Aired']]
anime_data.head()
# Out:
#                               Name                         Aired
# 0                     Cowboy Bebop   Apr 3, 1998 to Apr 24, 1999
# 1  Cowboy Bebop: Tengoku no Tobira                   Sep 1, 2001
# 2                           Trigun   Apr 1, 1998 to Sep 30, 1998
# 3               Witch Hunter Robin   Jul 3, 2002 to Dec 25, 2002
# 4                   Bouken Ou Beet  Sep 30, 2004 to Sep 29, 2005

# %%
anime_data[['start','end']] = anime_data['Aired'].str.split('to',expand=True)
anime_data.head()
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_11044\4134649139.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_data[['start','end']] = anime_data['Aired'].str.split('to',expand=True)
# C:\Users\pedro\AppData\Local\Temp\ipykernel_11044\4134649139.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_data[['start','end']] = anime_data['Aired'].str.split('to',expand=True)
#                               Name                         Aired  \
# 0                     Cowboy Bebop   Apr 3, 1998 to Apr 24, 1999
# 1  Cowboy Bebop: Tengoku no Tobira                   Sep 1, 2001
# 2                           Trigun   Apr 1, 1998 to Sep 30, 1998
# 3               Witch Hunter Robin   Jul 3, 2002 to Dec 25, 2002
# 4                   Bouken Ou Beet  Sep 30, 2004 to Sep 29, 2005
#
#            start            end
# 0   Apr 3, 1998    Apr 24, 1999
# 1    Sep 1, 2001           None
# 2   Apr 1, 1998    Sep 30, 1998
# 3   Jul 3, 2002    Dec 25, 2002
# 4  Sep 30, 2004    Sep 29, 2005

# %%
anime_data.drop(columns='Aired',inplace=True)
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_11044\2093283432.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_data.drop(columns='Aired',inplace=True)

# %%
anime_data.head()
# Out:
#                               Name          start            end
# 0                     Cowboy Bebop   Apr 3, 1998    Apr 24, 1999
# 1  Cowboy Bebop: Tengoku no Tobira    Sep 1, 2001           None
# 2                           Trigun   Apr 1, 1998    Sep 30, 1998
# 3               Witch Hunter Robin   Jul 3, 2002    Dec 25, 2002
# 4                   Bouken Ou Beet  Sep 30, 2004    Sep 29, 2005

# %%
anime_data['start'] = anime_data['start'].str.replace(r'\s+', ' ', regex=True).str.strip()
anime_data['start'] = pd.to_datetime(anime_data['start'], errors='coerce')
anime_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24905 entries, 0 to 24904
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    24905 non-null  object
#  1   start   20090 non-null  datetime64[ns]
#  2   end     11655 non-null  object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 583.8+ KB
# C:\Users\pedro\AppData\Local\Temp\ipykernel_11044\2029024098.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_data['start'] = anime_data['start'].str.replace(r'\s+', ' ', regex=True).str.strip()
# C:\Users\pedro\AppData\Local\Temp\ipykernel_11044\2029024098.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_data['start'] = pd.to_datetime(anime_data['start'], errors='coerce')

# %%
anime_data['ano'] = anime_data['start'].dt.year.astype('Int64')
anime_data.drop(columns=['start','end'],inplace=True)
anime_data
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_11044\75155296.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_data['ano'] = anime_data['start'].dt.year.astype('Int64')
# C:\Users\pedro\AppData\Local\Temp\ipykernel_11044\75155296.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_data.drop(columns=['start','end'],inplace=True)
#                                   Name   ano
# 0                         Cowboy Bebop  1998
# 1      Cowboy Bebop: Tengoku no Tobira  2001
# 2                               Trigun  1998
# 3                   Witch Hunter Robin  2002
# 4                       Bouken Ou Beet  2004
# ...                                ...   ...
# 24900                      Wu Nao Monu  2023
# 24901              Bu Xing Si: Yuan Qi  2023
# 24902                      Di Yi Xulie  2023
# 24903         Bokura no Saishuu Sensou  2022
# 24904                   Shijuuku Nichi  2022
#
# [24905 rows x 2 columns]

# %%
anime_ano[['ano','quantidade']] = anime_data.groupby('ano')['Name'].count().reset_index().sort_values('ano',ascending=True).reset_index(drop=True)

# %%
anime_ano.drop(columns='Name',inplace=True)

# %%
anime_ano
# Out:
#      ano  quantidade
# 0   1917          12
# 1   1918           9
# 2   1926           1
# 3   1927           2
# 4   1928           2
# ..   ...         ...
# 87  2019         987
# 88  2020         982
# 89  2021        1062
# 90  2022        1018
# 91  2023         506
#
# [92 rows x 2 columns]

# %%
anime_ano.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ano         92 non-null     Int64
#  1   quantidade  92 non-null     int64
# dtypes: Int64(1), int64(1)
# memory usage: 1.7 KB

# %%
decadas = []
for i in range(min((anime_ano['ano']//10)*10),max(anime_ano['ano']),10):
    decadas.append(i)

decadas
# Out:
# [1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020]

# %%
plt.bar(x=anime_ano['ano'],
        height=anime_ano['quantidade'])

plt.xlabel("Ano")
plt.ylabel("Quantidade")
plt.xticks(ticks=decadas, labels=decadas, rotation= 45)
plt.tight_layout()

plt.savefig('plot.png')
plt.show()

# %% [markdown]
# ### Avançado +

# %% [markdown]
# #### 16. Para cada tipo de anime (“Type”), quais são os 3 gêneros mais frequentes? Monte uma tabela resumo.

# %%
tipo_generos = dados[['Type','Genres','Name']]
tipo_generos['Genres'] = tipo_generos['Genres'].str.split(',')
tipo_generos = tipo_generos.explode('Genres')
tipo_generos
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_11044\1181542357.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tipo_generos['Genres'] = tipo_generos['Genres'].str.split(',')
#         Type          Genres                             Name
# 0         TV          Action                     Cowboy Bebop
# 0         TV   Award Winning                     Cowboy Bebop
# 0         TV          Sci-Fi                     Cowboy Bebop
# 1      Movie          Action  Cowboy Bebop: Tengoku no Tobira
# 1      Movie          Sci-Fi  Cowboy Bebop: Tengoku no Tobira
# ...      ...             ...                              ...
# 24902    ONA       Adventure                      Di Yi Xulie
# 24902    ONA         Fantasy                      Di Yi Xulie
# 24902    ONA          Sci-Fi                      Di Yi Xulie
# 24903  Music         UNKNOWN         Bokura no Saishuu Sensou
# 24904  Music         UNKNOWN                   Shijuuku Nichi
#
# [43390 rows x 3 columns]

# %%
tipo_generos_quantidade = tipo_generos.groupby(['Type','Genres'])['Name'].count().reset_index().sort_values(['Type','Name'],ascending=[True,False]).reset_index(drop=True)
tipo_generos_quantidade.rename(columns={'Name':'Quantidade'},
                               inplace=True)
tipo_generos_quantidade
# Out:
#         Type          Genres  Quantidade
# 0      Movie          Action         847
# 1      Movie         Fantasy         818
# 2      Movie       Adventure         705
# 3      Movie         UNKNOWN         696
# 4      Movie          Sci-Fi         583
# ..       ...             ...         ...
# 259  UNKNOWN      Girls Love           1
# 260  UNKNOWN         Gourmet           1
# 261  UNKNOWN         Mystery           1
# 262  UNKNOWN   Slice of Life           1
# 263  UNKNOWN         Mystery           1
#
# [264 rows x 3 columns]

# %%
tipos = list(tipo_generos_quantidade['Type'].unique())
tipos
# Out:
# ['Movie', 'Music', 'ONA', 'OVA', 'Special', 'TV', 'UNKNOWN']

# %%
resultado = []
for t in tipos:
    for i in range(3):
        try:
            resultado.append(tipo_generos_quantidade.loc[tipo_generos_quantidade['Type']==t].iloc[i])
        except IndexError:
            pass

resultado = pd.DataFrame(resultado).reset_index(drop=True)
resultado
# Out:
#        Type       Genres  Quantidade
# 0     Movie       Action         847
# 1     Movie      Fantasy         818
# 2     Movie    Adventure         705
# 3     Music      UNKNOWN        2020
# 4     Music  Avant Garde         173
# 5     Music      Fantasy          77
# 6       ONA       Comedy        1116
# 7       ONA       Action         788
# 8       ONA      Fantasy         685
# 9       OVA       Hentai        1129
# 10      OVA       Action         760
# 11      OVA       Comedy         594
# 12  Special       Comedy         929
# 13  Special       Action         539
# 14  Special      Fantasy         352
# 15       TV       Comedy        1914
# 16       TV       Action        1708
# 17       TV      Fantasy        1320
# 18  UNKNOWN       Action          22
# 19  UNKNOWN      Fantasy          16
# 20  UNKNOWN      UNKNOWN          15

# %% [markdown]
# #### 17. Quais são os 5 pares de “Estúdio + Gênero” mais comuns na base (após explodir “Genres”)?

# %%
estudio_genero = dados[['Studios','Genres']]
estudio_genero['Genres'] = estudio_genero['Genres'].str.split(',')
estudio_genero = estudio_genero.explode('Genres')
estudio_genero.reset_index(inplace=True)
estudio_genero
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_14052\1999385500.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   estudio_genero['Genres'] = estudio_genero['Genres'].str.split(',')
#        index  Studios          Genres
# 0          0  Sunrise          Action
# 1          0  Sunrise   Award Winning
# 2          0  Sunrise          Sci-Fi
# 3          1    Bones          Action
# 4          1    Bones          Sci-Fi
# ...      ...      ...             ...
# 43385  24902  UNKNOWN       Adventure
# 43386  24902  UNKNOWN         Fantasy
# 43387  24902  UNKNOWN          Sci-Fi
# 43388  24903  UNKNOWN         UNKNOWN
# 43389  24904  UNKNOWN         UNKNOWN
#
# [43390 rows x 3 columns]

# %%
estudio_genero = estudio_genero.groupby(['Studios','Genres'])['index'].count().reset_index()
estudio_genero.rename(columns={'index':'Contagem'},inplace=True)
estudio_genero.sort_values('Contagem',ascending=False,inplace=True)
estudio_genero.reset_index(drop=True,inplace=True)
estudio_genero
# Out:
#                         Studios     Genres  Contagem
# 0                       UNKNOWN    UNKNOWN      3773
# 1                       UNKNOWN     Comedy      1624
# 2                       UNKNOWN    Fantasy      1094
# 3                       UNKNOWN    Fantasy       963
# 4                       UNKNOWN  Adventure       908
# ...                         ...        ...       ...
# 6957                  Gathering  Boys Love         1
# 6958  pH Studio, D & D Pictures  Adventure         1
# 6959                  Gathering    Gourmet         1
# 6960                  pH Studio  Adventure         1
# 6961                     5 Inc.     Horror         1
#
# [6962 rows x 3 columns]

# %% [markdown]
# #### 18. Existe algum gênero exclusivo de “Movie” ou “ONA” (Online Animation)? Liste-os.

# %%
tipo_generos = dados[['Type','Genres']]
tipo_generos['Genres'] = tipo_generos['Genres'].str.split(',')
tipo_generos = tipo_generos.explode('Genres').reset_index()

tipo_generos
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_14052\1904044286.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tipo_generos['Genres'] = tipo_generos['Genres'].str.split(',')
#        index   Type          Genres
# 0          0     TV          Action
# 1          0     TV   Award Winning
# 2          0     TV          Sci-Fi
# 3          1  Movie          Action
# 4          1  Movie          Sci-Fi
# ...      ...    ...             ...
# 43385  24902    ONA       Adventure
# 43386  24902    ONA         Fantasy
# 43387  24902    ONA          Sci-Fi
# 43388  24903  Music         UNKNOWN
# 43389  24904  Music         UNKNOWN
#
# [43390 rows x 3 columns]

# %%
pivotado = pd.pivot_table(
    tipo_generos,
    values= 'index',
    index= 'Genres',
    columns='Type',
    aggfunc= 'count',
    observed= True,
    fill_value= 0
)
pivotado
# Out:
# Type            Movie  Music   ONA   OVA  Special    TV  UNKNOWN
# Genres
#  Adventure        325      1   267   211      182   581        6
#  Avant Garde        8      5     2     3        2     3        0
#  Award Winning     53      0     0     9        0    28        0
#  Boys Love          1      0     4     8        2     8        0
#  Comedy           424      9   192   326      284   762        5
#  Drama            357     11    96   255      120   522        5
#  Ecchi             17      2    32   234      140   315        3
#  Erotica            9      1     4    28        3     2        0
#  Fantasy          818     28   685   404      352  1320       16
#  Girls Love         7      1     6    15       12    44        1
#  Gourmet            9      1    21     1       11    51        1
#  Hentai             5      0    25   264       11     0        0
#  Horror            84      6    43    91       29   113        0
#  Mystery          127      4    89    88       91   285        1
#  Romance          228     17   197   349      169   785       11
#  Sci-Fi           583     37   238   497      291  1015       11
#  Slice of Life    153     14   199   104      176   452        1
#  Sports            87      1    25    36       61   160        2
#  Supernatural     195     16   216   237      173   492        5
#  Suspense          55      2    45    21       22    78        2
# Action            847     66   788   760      539  1708       22
# Adventure         705     22   172   230      208   925        7
# Avant Garde       466    173    65    16       41    20        0
# Award Winning     115      0     3     4        1    28        0
# Boys Love          18      3    33    60        9    23        0
# Comedy            531     47  1116   594      929  1914        9
# Drama             403     60   127   355      147   373        5
# Ecchi               1      5     5    10       25     6        0
# Erotica             2      0     1     4        0     0        0
# Fantasy           271     77   306   247       94   684        4
# Girls Love          3      0     3    17        1     3        0
# Gourmet             3      6    13     2        5    22        0
# Hentai              2      0    32  1129       18     0        0
# Horror             19      9    38    51       15    36        0
# Mystery            24      5    14    35       19    64        1
# Romance            24     66    52    70       44    48        3
# Sci-Fi             70     46    73    63       59   108        0
# Slice of Life      88     44   199    40      103   178        4
# Sports             69      6    43    55       60   164        2
# Supernatural       19     27    22    43       25    22        2
# Suspense            5      4     1     1        2     4        0
# UNKNOWN           696   2020   427   290      214  1267       15

# %%
movie_ona = ['Movie', 'ONA']
outros_tipos = [col for col in pivotado.columns if col not in movie_ona]
outros_tipos
# Out:
# ['Music', 'OVA', 'Special', 'TV', 'UNKNOWN']

# %%
exclusivos = pivotado[(pivotado[movie_ona].sum(axis=1) > 0) & (pivotado[outros_tipos].sum(axis=1) == 0)]
exclusivos
# Out:
# Empty DataFrame
# Columns: [Movie, Music, ONA, OVA, Special, TV, UNKNOWN]
# Index: []

# %% [markdown]
# #### 19. Faça uma linha do tempo dos lançamentos, plotando a quantidade de animes lançados por ano.

# %%
anime_data = dados[['Name','Aired']]
anime_data[['start','end']] = anime_data['Aired'].str.split('to',expand=True)
anime_data.drop(columns=['Aired','end'],inplace=True)
anime_data
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_13688\2157872635.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_data[['start','end']] = anime_data['Aired'].str.split('to',expand=True)
# C:\Users\pedro\AppData\Local\Temp\ipykernel_13688\2157872635.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_data[['start','end']] = anime_data['Aired'].str.split('to',expand=True)
# C:\Users\pedro\AppData\Local\Temp\ipykernel_13688\2157872635.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_data.drop(columns=['Aired','end'],inplace=True)
#                                   Name          start
# 0                         Cowboy Bebop   Apr 3, 1998
# 1      Cowboy Bebop: Tengoku no Tobira    Sep 1, 2001
# 2                               Trigun   Apr 1, 1998
# 3                   Witch Hunter Robin   Jul 3, 2002
# 4                       Bouken Ou Beet  Sep 30, 2004
# ...                                ...            ...
# 24900                      Wu Nao Monu   Jul 4, 2023
# 24901              Bu Xing Si: Yuan Qi  Jul 27, 2023
# 24902                      Di Yi Xulie  Jul 19, 2023
# 24903         Bokura no Saishuu Sensou   Apr 23, 2022
# 24904                   Shijuuku Nichi    Sep 5, 2022
#
# [24905 rows x 2 columns]

# %%
anime_data['start'] = anime_data['start'].str.replace(r'\s+', ' ', regex=True)
anime_data['start'] = anime_data['start'].str.replace(r'\s+', ' ', regex=True).str.strip()
anime_data['start'] = pd.to_datetime(anime_data['start'], errors='coerce')
anime_data
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_13688\2308154406.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_data['start'] = anime_data['start'].str.replace(r'\s+', ' ', regex=True)
# C:\Users\pedro\AppData\Local\Temp\ipykernel_13688\2308154406.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_data['start'] = anime_data['start'].str.replace(r'\s+', ' ', regex=True).str.strip()
# C:\Users\pedro\AppData\Local\Temp\ipykernel_13688\2308154406.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_data['start'] = pd.to_datetime(anime_data['start'], errors='coerce')
#                                   Name      start
# 0                         Cowboy Bebop 1998-04-03
# 1      Cowboy Bebop: Tengoku no Tobira 2001-09-01
# 2                               Trigun 1998-04-01
# 3                   Witch Hunter Robin 2002-07-03
# 4                       Bouken Ou Beet 2004-09-30
# ...                                ...        ...
# 24900                      Wu Nao Monu 2023-07-04
# 24901              Bu Xing Si: Yuan Qi 2023-07-27
# 24902                      Di Yi Xulie 2023-07-19
# 24903         Bokura no Saishuu Sensou 2022-04-23
# 24904                   Shijuuku Nichi 2022-09-05
#
# [24905 rows x 2 columns]

# %%
ano_anime = anime_data
ano_anime['start'] = ano_anime['start'].dt.year.astype('Int64')
ano_anime
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_13688\3340112781.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ano_anime['start'] = ano_anime['start'].dt.year.astype('Int64')
#                                   Name  start
# 0                         Cowboy Bebop   1998
# 1      Cowboy Bebop: Tengoku no Tobira   2001
# 2                               Trigun   1998
# 3                   Witch Hunter Robin   2002
# 4                       Bouken Ou Beet   2004
# ...                                ...    ...
# 24900                      Wu Nao Monu   2023
# 24901              Bu Xing Si: Yuan Qi   2023
# 24902                      Di Yi Xulie   2023
# 24903         Bokura no Saishuu Sensou   2022
# 24904                   Shijuuku Nichi   2022
#
# [24905 rows x 2 columns]

# %%
# ano_anime = ano_anime.groupby('start')['Name'].count().reset_index().sort_values('start')
# ano_anime.rename(columns={'Name':'Quantidade'},inplace=True)
# ano_anime
# Out:
#     start  Quantidade
# 0    1917          12
# 1    1918           9
# 2    1926           1
# 3    1927           2
# 4    1928           2
# ..    ...         ...
# 87   2019         987
# 88   2020         982
# 89   2021        1062
# 90   2022        1018
# 91   2023         506
#
# [92 rows x 2 columns]

# %%
decadas = []
for i in range((min(ano_anime['start'])//10)*10,(max(ano_anime['start'])//10+1)*10,10):
    decadas.append(i)

decadas
# Out:
# [1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020]

# %%
plt.scatter(x=ano_anime['start'],
            y=ano_anime['Quantidade'])
plt.xlabel("Ano")
plt.ylabel("Quantidade")
plt.xticks(decadas,rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# #### 20. Existe correlação visual entre a popularidade (“Popularity”) e o número de membros (“Members”)? Monte um scatter plot.

# %%
pop_membros = dados[['Popularity','Members']]
pop_membros.sort_values('Popularity',ascending=True, inplace=True)
pop_membros
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_13688\2570884193.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pop_membros.sort_values('Popularity',ascending=True, inplace=True)
#        Popularity  Members
# 24897           0        0
# 24904           0        0
# 24896           0        0
# 24903           0        0
# 24556           0        0
# ...           ...      ...
# 24655       24710       23
# 24668       24713       22
# 24747       24715       21
# 24125       24717       15
# 24900       24723        0
#
# [24905 rows x 2 columns]

# %%
plt.scatter(x=pop_membros['Popularity'],
            y=pop_membros['Members'])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Brabo

# %% [markdown]
# #### 21. Encontre animes com nomes iguais (“Name”), mas exibidos em anos diferentes (“Aired”) ou por estúdios diferentes. Quantos casos assim existem?

# %%
nomes = list(dados['Name'][dados['Name'].duplicated()])
nomes
# Out:
# ['Azur Lane', 'Utopia', 'Souseiki', 'Awakening']

# %%
final = []
for n in range(len(nomes)):
    final.append(dados[dados['Name'] == nomes[n]])

final_df = pd.concat(final, ignore_index=True)

final_df[['Name','Aired']]
# Out:
#         Name                        Aired
# 0  Azur Lane  Oct 3, 2019 to Mar 20, 2020
# 1  Azur Lane            Apr 17, 2020 to ?
# 2     Utopia                 Feb 26, 2014
# 3     Utopia                 Aug 12, 2021
# 4   Souseiki                  Oct 1, 1968
# 5   Souseiki                Not available
# 6  Awakening                 May 11, 2020
# 7  Awakening                 Oct 30, 2002

# %% [markdown]
# #### 22. Monte um heatmap cruzando os 10 gêneros mais populares com as 10 produtoras mais frequentes.

# %%
generos_produtoras = dados[['Name','Genres','Producers']]
generos_produtoras['Genres'] = generos_produtoras['Genres'].str.split(',')
generos_produtoras = generos_produtoras.explode('Genres')
generos_produtoras['Producers'] = generos_produtoras['Producers'].str.split(',')
generos_produtoras = generos_produtoras.explode('Producers')
generos_produtoras
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_22452\2638861038.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   generos_produtoras['Genres'] = generos_produtoras['Genres'].str.split(',')
#                                   Name          Genres       Producers
# 0                         Cowboy Bebop          Action   Bandai Visual
# 0                         Cowboy Bebop   Award Winning   Bandai Visual
# 0                         Cowboy Bebop          Sci-Fi   Bandai Visual
# 1      Cowboy Bebop: Tengoku no Tobira          Action         Sunrise
# 1      Cowboy Bebop: Tengoku no Tobira          Action   Bandai Visual
# ...                                ...             ...             ...
# 24902                      Di Yi Xulie       Adventure         UNKNOWN
# 24902                      Di Yi Xulie         Fantasy         UNKNOWN
# 24902                      Di Yi Xulie          Sci-Fi         UNKNOWN
# 24903         Bokura no Saishuu Sensou         UNKNOWN         UNKNOWN
# 24904                   Shijuuku Nichi         UNKNOWN         UNKNOWN
#
# [75525 rows x 3 columns]

# %%
top_gen = list(generos_produtoras.groupby('Genres')['Name'].count().reset_index().sort_values('Name',ascending=False).head(10)['Genres'])
top_gen
# Out:
# ['Action',
#  'Comedy',
#  ' Fantasy',
#  'UNKNOWN',
#  ' Sci-Fi',
#  ' Romance',
#  ' Comedy',
#  'Adventure',
#  ' Adventure',
#  ' Drama']

# %%
top_prd = list(generos_produtoras.groupby('Producers')['Name'].count().reset_index().sort_values('Name',ascending=False).head(10)['Producers'])
top_prd
# Out:
# ['UNKNOWN',
#  'TV Tokyo',
#  'Aniplex',
#  'Bandai Visual',
#  'NHK',
#  ' Movic',
#  ' Kadokawa',
#  ' AT-X',
#  ' KlockWorx',
#  ' Kodansha']

# %%
pivotado = pd.pivot_table(
    generos_produtoras,
    values='Name',
    index='Genres',
    columns='Producers',
    aggfunc='count',
    fill_value=0
).astype(int)
pivotado = pivotado.loc[top_gen,top_prd]
pivotado
# Out:
# Producers   UNKNOWN  TV Tokyo  Aniplex  Bandai Visual  NHK   Movic   Kadokawa  \
# Genres
# Action         1761       215      212            163   18     137        105
# Comedy         2680       112      131             82   72      75         62
#  Fantasy       1649       143      128             73   33      83        120
# UNKNOWN        3582        19       15              4  510       7          7
#  Sci-Fi        1066        99       87            165   18      63         45
#  Romance        506        60       90             57   21      82         60
#  Comedy         833       132       47             48   17      47         38
# Adventure      1317        73       25             44   62      19         37
#  Adventure      564       109       47             45    9      29         27
#  Drama          416        31       56             80   18      44         29
#
# Producers    AT-X   KlockWorx   Kodansha
# Genres
# Action        110         108         84
# Comedy         75          85         73
#  Fantasy       84          69         43
# UNKNOWN         3           3          2
#  Sci-Fi        44          46         24
#  Romance       67          76         56
#  Comedy        42          39         15
# Adventure      18          11         16
#  Adventure     17          26         24
#  Drama         20          17         44

# %%
sns.heatmap(pivotado, cmap='Blues', annot=True, fmt='d', linewidths=1)
plt.title("Heatmap dos 10 gêneros mais populares x 10 produtoras mais frequentes")
plt.tight_layout()
plt.savefig('heatmap.png')
plt.show()

# %% [markdown]
# #### 23. Qual anime ficou mais tempo com status em “Currently Airing” desde sua estreia (“Aired”)?

# %%
tempo = dados[['Name','Aired']]
tempo
# Out:
#                                   Name                         Aired
# 0                         Cowboy Bebop   Apr 3, 1998 to Apr 24, 1999
# 1      Cowboy Bebop: Tengoku no Tobira                   Sep 1, 2001
# 2                               Trigun   Apr 1, 1998 to Sep 30, 1998
# 3                   Witch Hunter Robin   Jul 3, 2002 to Dec 25, 2002
# 4                       Bouken Ou Beet  Sep 30, 2004 to Sep 29, 2005
# ...                                ...                           ...
# 24900                      Wu Nao Monu              Jul 4, 2023 to ?
# 24901              Bu Xing Si: Yuan Qi             Jul 27, 2023 to ?
# 24902                      Di Yi Xulie             Jul 19, 2023 to ?
# 24903         Bokura no Saishuu Sensou                  Apr 23, 2022
# 24904                   Shijuuku Nichi                   Sep 5, 2022
#
# [24905 rows x 2 columns]

# %%
tempo[['start','end']] = tempo['Aired'].str.split('to',expand=True)
tempo.drop(columns='Aired',inplace=True)
tempo
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_22452\3005714057.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempo[['start','end']] = tempo['Aired'].str.split('to',expand=True)
# C:\Users\pedro\AppData\Local\Temp\ipykernel_22452\3005714057.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempo[['start','end']] = tempo['Aired'].str.split('to',expand=True)
# C:\Users\pedro\AppData\Local\Temp\ipykernel_22452\3005714057.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempo.drop(columns='Aired',inplace=True)
#                                   Name          start            end
# 0                         Cowboy Bebop   Apr 3, 1998    Apr 24, 1999
# 1      Cowboy Bebop: Tengoku no Tobira    Sep 1, 2001           None
# 2                               Trigun   Apr 1, 1998    Sep 30, 1998
# 3                   Witch Hunter Robin   Jul 3, 2002    Dec 25, 2002
# 4                       Bouken Ou Beet  Sep 30, 2004    Sep 29, 2005
# ...                                ...            ...            ...
# 24900                      Wu Nao Monu   Jul 4, 2023               ?
# 24901              Bu Xing Si: Yuan Qi  Jul 27, 2023               ?
# 24902                      Di Yi Xulie  Jul 19, 2023               ?
# 24903         Bokura no Saishuu Sensou   Apr 23, 2022           None
# 24904                   Shijuuku Nichi    Sep 5, 2022           None
#
# [24905 rows x 3 columns]

# %%
tempo['start'] = tempo['start'].str.replace(r'\s+', ' ', regex=True).str.strip()
tempo['start'] = pd.to_datetime(tempo['start'], errors='coerce')
tempo['end'] = tempo['end'].str.replace(r'\s+', ' ', regex=True).str.strip()
tempo['end'] = pd.to_datetime(tempo['end'], errors='coerce')
tempo['end'] = tempo['end'].fillna(pd.Timestamp.today().normalize())
tempo
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_22452\581254975.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempo['start'] = tempo['start'].str.replace(r'\s+', ' ', regex=True).str.strip()
# C:\Users\pedro\AppData\Local\Temp\ipykernel_22452\581254975.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempo['start'] = pd.to_datetime(tempo['start'], errors='coerce')
# C:\Users\pedro\AppData\Local\Temp\ipykernel_22452\581254975.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempo['end'] = tempo['end'].str.replace(r'\s+', ' ', regex=True).str.strip()
# C:\Users\pedro\AppData\Local\Temp\ipykernel_22452\581254975.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempo['end'] = pd.to_datetime(tempo['end'], errors='coerce')
# C:\Users\pedro\AppData\Local\Temp\ipykernel_22452\581254975.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempo['end'] = tempo['end'].fillna(pd.Timestamp.today().normalize())
#                                   Name      start        end
# 0                         Cowboy Bebop 1998-04-03 1999-04-24
# 1      Cowboy Bebop: Tengoku no Tobira 2001-09-01 2025-08-22
# 2                               Trigun 1998-04-01 1998-09-30
# 3                   Witch Hunter Robin 2002-07-03 2002-12-25
# 4                       Bouken Ou Beet 2004-09-30 2005-09-29
# ...                                ...        ...        ...
# 24900                      Wu Nao Monu 2023-07-04 2025-08-22
# 24901              Bu Xing Si: Yuan Qi 2023-07-27 2025-08-22
# 24902                      Di Yi Xulie 2023-07-19 2025-08-22
# 24903         Bokura no Saishuu Sensou 2022-04-23 2025-08-22
# 24904                   Shijuuku Nichi 2022-09-05 2025-08-22
#
# [24905 rows x 3 columns]

# %%
tempo['duração'] = (tempo['end']-tempo['start']).dt.days
tempo['duração'] = tempo['duração'].fillna(0).astype(int)
tempo
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_22452\3373996237.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempo['duração'] = (tempo['end']-tempo['start']).dt.days
# C:\Users\pedro\AppData\Local\Temp\ipykernel_22452\3373996237.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempo['duração'] = tempo['duração'].fillna(0).astype(int)
#                                   Name      start        end  duração
# 0                         Cowboy Bebop 1998-04-03 1999-04-24      386
# 1      Cowboy Bebop: Tengoku no Tobira 2001-09-01 2025-08-22     8756
# 2                               Trigun 1998-04-01 1998-09-30      182
# 3                   Witch Hunter Robin 2002-07-03 2002-12-25      175
# 4                       Bouken Ou Beet 2004-09-30 2005-09-29      364
# ...                                ...        ...        ...      ...
# 24900                      Wu Nao Monu 2023-07-04 2025-08-22      780
# 24901              Bu Xing Si: Yuan Qi 2023-07-27 2025-08-22      757
# 24902                      Di Yi Xulie 2023-07-19 2025-08-22      765
# 24903         Bokura no Saishuu Sensou 2022-04-23 2025-08-22     1217
# 24904                   Shijuuku Nichi 2022-09-05 2025-08-22     1082
#
# [24905 rows x 4 columns]

# %%
tempo.sort_values('duração',ascending=False)
# Out:
#                                                     Name      start  \
# 8835   Chamebou Shin Gachou: Nomi Fuufu Shikaeshi no ... 1917-04-28
# 6338                              Saru to Kani no Gassen 1917-05-20
# 4668                                     Namakura Gatana 1917-06-30
# 9126                                      Neko to Nezumi 1917-07-04
# 8833                                        Itazura Post 1917-07-28
# ...                                                  ...        ...
# 17838                         Qi Jiguang Yingxiong Chuan 2012-06-01
# 11672              Kurogane no Linebarrels Picture Drama 2009-12-14
# 3223                                      Flashback Game 2001-10-18
# 14896                                Tobidase! Dokan-kun 2011-10-26
# 21733  Tesla Note: Mickey to Oliver no Agent Yousei K... 2021-09-29
#
#              end  duração
# 8835  2025-08-22    39563
# 6338  2025-08-22    39541
# 4668  2025-08-22    39500
# 9126  2025-08-22    39496
# 8833  2025-08-22    39472
# ...          ...      ...
# 17838 2012-05-01      -31
# 11672 2009-08-26     -110
# 3223  2001-04-18     -183
# 14896 2011-03-14     -226
# 21733 2021-01-16     -256
#
# [24905 rows x 4 columns]

# %% [markdown]
# #### 24. Para cada ano, descubra quais gêneros surgiram pela primeira vez na base, criando uma linha do tempo de “estreias de gênero”.

# %%
gen_tmp = dados[['Genres','Aired']]
gen_tmp
# Out:
#                                      Genres                         Aired
# 0             Action, Award Winning, Sci-Fi   Apr 3, 1998 to Apr 24, 1999
# 1                            Action, Sci-Fi                   Sep 1, 2001
# 2                 Action, Adventure, Sci-Fi   Apr 1, 1998 to Sep 30, 1998
# 3      Action, Drama, Mystery, Supernatural   Jul 3, 2002 to Dec 25, 2002
# 4          Adventure, Fantasy, Supernatural  Sep 30, 2004 to Sep 29, 2005
# ...                                     ...                           ...
# 24900        Comedy, Fantasy, Slice of Life              Jul 4, 2023 to ?
# 24901            Action, Adventure, Fantasy             Jul 27, 2023 to ?
# 24902    Action, Adventure, Fantasy, Sci-Fi             Jul 19, 2023 to ?
# 24903                               UNKNOWN                  Apr 23, 2022
# 24904                               UNKNOWN                   Sep 5, 2022
#
# [24905 rows x 2 columns]

# %%
gen_tmp[['start','end']] = gen_tmp['Aired'].str.split('to',expand=True)
gen_tmp.drop(columns=['end','Aired'],inplace=True)
gen_tmp
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_22452\181329352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gen_tmp[['start','end']] = gen_tmp['Aired'].str.split('to',expand=True)
# C:\Users\pedro\AppData\Local\Temp\ipykernel_22452\181329352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gen_tmp[['start','end']] = gen_tmp['Aired'].str.split('to',expand=True)
# C:\Users\pedro\AppData\Local\Temp\ipykernel_22452\181329352.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gen_tmp.drop(columns=['end','Aired'],inplace=True)
#                                      Genres          start
# 0             Action, Award Winning, Sci-Fi   Apr 3, 1998
# 1                            Action, Sci-Fi    Sep 1, 2001
# 2                 Action, Adventure, Sci-Fi   Apr 1, 1998
# 3      Action, Drama, Mystery, Supernatural   Jul 3, 2002
# 4          Adventure, Fantasy, Supernatural  Sep 30, 2004
# ...                                     ...            ...
# 24900        Comedy, Fantasy, Slice of Life   Jul 4, 2023
# 24901            Action, Adventure, Fantasy  Jul 27, 2023
# 24902    Action, Adventure, Fantasy, Sci-Fi  Jul 19, 2023
# 24903                               UNKNOWN   Apr 23, 2022
# 24904                               UNKNOWN    Sep 5, 2022
#
# [24905 rows x 2 columns]

# %%
gen_tmp['Genres'] = gen_tmp['Genres'].str.split(',')
gen_tmp = gen_tmp.explode('Genres')
gen_tmp
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_22452\318848837.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gen_tmp['Genres'] = gen_tmp['Genres'].str.split(',')
#                Genres          start
# 0              Action   Apr 3, 1998
# 0       Award Winning   Apr 3, 1998
# 0              Sci-Fi   Apr 3, 1998
# 1              Action    Sep 1, 2001
# 1              Sci-Fi    Sep 1, 2001
# ...               ...            ...
# 24902       Adventure  Jul 19, 2023
# 24902         Fantasy  Jul 19, 2023
# 24902          Sci-Fi  Jul 19, 2023
# 24903         UNKNOWN   Apr 23, 2022
# 24904         UNKNOWN    Sep 5, 2022
#
# [43390 rows x 2 columns]

# %%
gen_tmp['start'] = gen_tmp['start'].str.replace(r'\s+', ' ', regex=True).str.strip()
gen_tmp['start'] = pd.to_datetime(gen_tmp['start'], errors='coerce')
gen_tmp = gen_tmp.reset_index(drop=True).sort_values('start')
gen_tmp
# Out:
#          Genres      start
# 18979    Comedy 1917-04-28
# 14483     Drama 1917-05-20
# 11321    Comedy 1917-06-30
# 19465    Comedy 1917-07-04
# 18977    Comedy 1917-07-28
# ...         ...        ...
# 43363   Fantasy        NaT
# 43364   Romance        NaT
# 43365   Fantasy        NaT
# 43366   Romance        NaT
# 43374    Action        NaT
#
# [43390 rows x 2 columns]

# %%
segundinha = gen_tmp[gen_tmp.duplicated('Genres')]
segundinha.index
# Out:
# Index([11321, 19465, 18977, 18978, 17341, 38779, 18981, 14489, 14490, 11959,
#        ...
#        43354, 43355, 43356, 43359, 43360, 43363, 43364, 43365, 43366, 43374],
#       dtype='int64', length=43348)

# %%
gen_tmp = gen_tmp.drop(index=list(segundinha.index)).reset_index(drop=True)
gen_tmp
# Out:
#             Genres      start
# 0           Comedy 1917-04-28
# 1            Drama 1917-05-20
# 2            Drama 1917-08-26
# 3          UNKNOWN 1917-10-10
# 4          Fantasy 1918-02-15
# 5          Romance 1926-10-06
# 6        Adventure 1926-10-06
# 7           Sports 1928-09-04
# 8          Fantasy 1929-03-12
# 9        Adventure 1929-03-12
# 10          Action 1929-03-12
# 11          Comedy 1931-10-01
# 12   Slice of Life 1933-12-01
# 13    Supernatural 1933-12-31
# 14          Sports 1934-11-16
# 15    Supernatural 1955-12-26
# 16   Award Winning 1962-11-05
# 17          Sci-Fi 1963-01-01
# 18   Award Winning 1963-03-24
# 19           Ecchi 1963-09-04
# 20         Mystery 1964-09-21
# 21          Sci-Fi 1965-02-01
# 22   Slice of Life 1965-08-29
# 23         Mystery 1966-11-14
# 24          Horror 1967-09-18
# 25          Horror 1968-10-07
# 26     Avant Garde 1968-10-12
# 27          Hentai 1969-10-29
# 28          Hentai 1971-09-24
# 29         Romance 1972-08-27
# 30        Suspense 1975-04-07
# 31           Ecchi 1980-04-19
# 32       Boys Love 1981-03-20
# 33       Boys Love 1982-04-08
# 34      Girls Love 1985-03-10
# 35         Gourmet 1987-10-08
# 36         Erotica 1990-04-27
# 37         Erotica 1990-06-22
# 38     Avant Garde 1990-12-22
# 39         Gourmet 1991-06-21
# 40      Girls Love 1991-07-14
# 41        Suspense 2003-04-25

# %%
gen_tmp['start'] = gen_tmp['start'].dt.year.astype('Int64')
gen_tmp
# Out:
#             Genres  start
# 0           Comedy   1917
# 1            Drama   1917
# 2            Drama   1917
# 3          UNKNOWN   1917
# 4          Fantasy   1918
# 5          Romance   1926
# 6        Adventure   1926
# 7           Sports   1928
# 8          Fantasy   1929
# 9        Adventure   1929
# 10          Action   1929
# 11          Comedy   1931
# 12   Slice of Life   1933
# 13    Supernatural   1933
# 14          Sports   1934
# 15    Supernatural   1955
# 16   Award Winning   1962
# 17          Sci-Fi   1963
# 18   Award Winning   1963
# 19           Ecchi   1963
# 20         Mystery   1964
# 21          Sci-Fi   1965
# 22   Slice of Life   1965
# 23         Mystery   1966
# 24          Horror   1967
# 25          Horror   1968
# 26     Avant Garde   1968
# 27          Hentai   1969
# 28          Hentai   1971
# 29         Romance   1972
# 30        Suspense   1975
# 31           Ecchi   1980
# 32       Boys Love   1981
# 33       Boys Love   1982
# 34      Girls Love   1985
# 35         Gourmet   1987
# 36         Erotica   1990
# 37         Erotica   1990
# 38     Avant Garde   1990
# 39         Gourmet   1991
# 40      Girls Love   1991
# 41        Suspense   2003

# %%
gen_tmp.sort_values('start').reset_index(drop=True)
# Out:
#             Genres  start
# 0           Comedy   1917
# 1            Drama   1917
# 2            Drama   1917
# 3          UNKNOWN   1917
# 4          Fantasy   1918
# 5          Romance   1926
# 6        Adventure   1926
# 7           Sports   1928
# 8          Fantasy   1929
# 9        Adventure   1929
# 10          Action   1929
# 11          Comedy   1931
# 12   Slice of Life   1933
# 13    Supernatural   1933
# 14          Sports   1934
# 15    Supernatural   1955
# 16   Award Winning   1962
# 17          Sci-Fi   1963
# 18   Award Winning   1963
# 19           Ecchi   1963
# 20         Mystery   1964
# 21          Sci-Fi   1965
# 22   Slice of Life   1965
# 23         Mystery   1966
# 24          Horror   1967
# 25          Horror   1968
# 26     Avant Garde   1968
# 27          Hentai   1969
# 28          Hentai   1971
# 29         Romance   1972
# 30        Suspense   1975
# 31           Ecchi   1980
# 32       Boys Love   1981
# 33       Boys Love   1982
# 34      Girls Love   1985
# 35         Gourmet   1987
# 36         Erotica   1990
# 37         Erotica   1990
# 38     Avant Garde   1990
# 39         Gourmet   1991
# 40      Girls Love   1991
# 41        Suspense   2003

# %%
decadas = []
for i in range((min(gen_tmp['start'])//10)*10,(max(gen_tmp['start'])//10+1)*10,10):
    decadas.append(i)

decadas
# Out:
# [1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000]

# %%
plt.scatter(x=gen_tmp['start'],
            y=gen_tmp.index,
            c ='r',marker='o')
plt.xticks(decadas,rotation=45)
plt.show()

# %% [markdown]
# #### 25. Existe algum estúdio presente em todos os tipos (“Type”) existentes no dataset? Listeos

# %%
studios_type = dados[['Studios','Type']].reset_index()
studios_type['Studios'] = studios_type['Studios'].str.split(',')
studios_type = studios_type.explode('Studios')
studios_type = studios_type.groupby(['Studios','Type'])['index'].count().reset_index()
studios_type
# Out:
#           Studios     Type  index
# 0       100studio       TV      1
# 1         10Gauge    Movie      1
# 2          5 Inc.      ONA      1
# 3      81 Produce      OVA      1
# 4            8bit    Movie      2
# ...           ...      ...    ...
# 2557     ufotable    Music      1
# 2558     ufotable      ONA      5
# 2559     ufotable      OVA      7
# 2560     ufotable  Special     21
# 2561     ufotable       TV     19
#
# [2562 rows x 3 columns]

# %%
studios_type = studios_type.groupby('Studios')['Type'].count().reset_index()
studios_type
# Out:
#             Studios  Type
# 0         100studio     1
# 1           10Gauge     1
# 2            5 Inc.     1
# 3        81 Produce     1
# 4              8bit     2
# ...             ...   ...
# 1351  studio MOTHER     2
# 1352     studio YOG     1
# 1353      studio hb     1
# 1354        trenova     1
# 1355       ufotable     6
#
# [1356 rows x 2 columns]

# %%
todos_tipos = dados['Type'].nunique()
todos_tipos
# Out:
# 7

# %%
studios_type.loc[studios_type['Type']==todos_tipos]
# Out:
#              Studios  Type
# 833         Madhouse     7
# 1195         Sunrise     7
# 1241  Toei Animation     7
# 1277         UNKNOWN     7

# %% [markdown]
# ### Brabo +

# %% [markdown]
# #### 26. Implemente a detecção de tendências: Qual gênero mais cresceu em número de animes de uma década para outra?

# %%
gen_tmp = dados[['Genres','Aired']]
gen_tmp['Genres'] = gen_tmp['Genres'].str.split(',')
gen_tmp = gen_tmp.explode('Genres')
gen_tmp[['start','end']]=gen_tmp['Aired'].str.split('to',expand=True)
gen_tmp.drop(columns=['Aired','end'],inplace=True)
gen_tmp
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_4628\2882973478.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gen_tmp['Genres'] = gen_tmp['Genres'].str.split(',')
#                Genres          start
# 0              Action   Apr 3, 1998
# 0       Award Winning   Apr 3, 1998
# 0              Sci-Fi   Apr 3, 1998
# 1              Action    Sep 1, 2001
# 1              Sci-Fi    Sep 1, 2001
# ...               ...            ...
# 24902       Adventure  Jul 19, 2023
# 24902         Fantasy  Jul 19, 2023
# 24902          Sci-Fi  Jul 19, 2023
# 24903         UNKNOWN   Apr 23, 2022
# 24904         UNKNOWN    Sep 5, 2022
#
# [43390 rows x 2 columns]

# %%
gen_tmp['start'] = gen_tmp['start'].str.replace(r'\s+', ' ', regex=True).str.strip()
gen_tmp['start'] = pd.to_datetime(gen_tmp['start'], errors='coerce')
gen_tmp = gen_tmp.reset_index(drop=True).sort_values('start')
gen_tmp['start'] = gen_tmp['start'].dt.year.astype('Int64')
gen_tmp.dropna(inplace=True)
gen_tmp.reset_index(drop=True,inplace=True)
gen_tmp
# Out:
#               Genres  start
# 0             Comedy   1917
# 1              Drama   1917
# 2             Comedy   1917
# 3             Comedy   1917
# 4             Comedy   1917
# ...              ...    ...
# 37266   Supernatural   2023
# 37267         Comedy   2023
# 37268        Fantasy   2023
# 37269         Comedy   2023
# 37270         Action   2023
#
# [37271 rows x 2 columns]

# %%
decadas=[]
for i in range((min(gen_tmp['start'])//10)*10,(max(gen_tmp['start'])//10+2)*10,10):
    decadas.append(i)
decadas
# Out:
# [1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020, 2030]

# %%
resultado = []
for i in range(len(decadas)-1):
    resultado = (gen_tmp['start'] >= decadas[i]) & (gen_tmp['start']<decadas[i+1])
    gen_tmp.loc[resultado,'decada'] = decadas[i]
gen_tmp['decada'] = gen_tmp['decada'].astype(int)
gen_tmp
# Out:
#               Genres  start  decada
# 0             Comedy   1917    1910
# 1              Drama   1917    1910
# 2             Comedy   1917    1910
# 3             Comedy   1917    1910
# 4             Comedy   1917    1910
# ...              ...    ...     ...
# 37266   Supernatural   2023    2020
# 37267         Comedy   2023    2020
# 37268        Fantasy   2023    2020
# 37269         Comedy   2023    2020
# 37270         Action   2023    2020
#
# [37271 rows x 3 columns]

# %%
gen_tmp.sort_values('decada',ascending=True,inplace=True)
gen_tmp
# Out:
#         Genres  start  decada
# 0       Comedy   1917    1910
# 1        Drama   1917    1910
# 5       Comedy   1917    1910
# 2       Comedy   1917    1910
# 6       Comedy   1917    1910
# ...        ...    ...     ...
# 37258  UNKNOWN   2023    2020
# 37257   Action   2023    2020
# 37240   Comedy   2023    2020
# 37270   Action   2023    2020
# 37239   Action   2023    2020
#
# [37271 rows x 3 columns]

# %%
pivotado = pd.pivot_table(
    gen_tmp,
    values = 'start',
    index = 'decada',
    columns = 'Genres',
    aggfunc = 'count',
    observed = True,
    fill_value=0
)

pivotado
# Out:
# Genres   Adventure   Avant Garde   Award Winning   Boys Love   Comedy   Drama  \
# decada
# 1910             0             0               0           0        0       1
# 1920             1             0               0           0        0       0
# 1930             1             0               0           0        3       1
# 1940             1             0               0           0        0       0
# 1950             0             0               0           0        0       0
# 1960            23             0               1           0       11      10
# 1970            43             0               2           0       27      41
# 1980           129             0               7           2      136     131
# 1990           235             4              15           3      363     208
# 2000           303             6              30           8      491     395
# 2010           455             7              20           9      630     352
# 2020           280             2               8           1      203     138
#
# Genres   Ecchi   Erotica   Fantasy   Girls Love  ...  Hentai  Horror  Mystery  \
# decada                                           ...
# 1910         0         0         0            0  ...       0       0        0
# 1920         0         0         1            0  ...       0       0        0
# 1930         0         0         0            0  ...       0       0        0
# 1940         0         0         1            0  ...       0       0        0
# 1950         0         0         2            0  ...       0       0        0
# 1960         1         0        15            0  ...       0       1        1
# 1970         0         0        33            0  ...       1       0        4
# 1980        21         0       142            0  ...      22      13        4
# 1990        84         6       362            8  ...      82      32        9
# 2000       218        14       638           27  ...     434      32       41
# 2010       353        19      1313           37  ...     481      58       57
# 2020        54         5       734            9  ...     158      16       38
#
# Genres  Romance  Sci-Fi  Slice of Life  Sports  Supernatural  Suspense  \
# decada
# 1910          0       0              0       0             0         0
# 1920          0       0              0       0             0         0
# 1930          0       0              1       1             0         0
# 1940          0       0              0       0             0         0
# 1950          0       0              0       0             1         0
# 1960          0       4              6       2             0         0
# 1970          2      12              1      12             2         0
# 1980         20      18             12      27             3         0
# 1990         31      29             15      28             9         0
# 2000         36      76             40      50            17         4
# 2010        132     154            335     165            76         4
# 2020         56      54            145      65            28         6
#
# Genres  UNKNOWN
# decada
# 1910          5
# 1920          3
# 1930         15
# 1940          5
# 1950          3
# 1960         30
# 1970         75
# 1980        138
# 1990        210
# 2000        356
# 2010       1425
# 2020        868
#
# [12 rows x 42 columns]

# %%
generos = pivotado.columns.to_list()
decadas = pivotado.index.to_list()

crescimento = []

for i in range(1,len(decadas)):
    decada_atual = pivotado.loc[decadas[i]]
    decada_anterior = pivotado.loc[decadas[i-1]]
    
    cresc = np.where(decada_anterior!=0,
                     decada_atual/decada_anterior,
                     np.nan).round(2)
    
    cresc_series = pd.Series(cresc, index= generos, name= decadas[i])
    crescimento.append(cresc_series)

crescimento = pd.DataFrame(crescimento)
crescimento
# Out:
#        Adventure   Avant Garde   Award Winning   Boys Love   Comedy   Drama  \
# 1920         NaN           NaN             NaN         NaN      NaN    0.00
# 1930        1.00           NaN             NaN         NaN      NaN     NaN
# 1940        1.00           NaN             NaN         NaN     0.00    0.00
# 1950        0.00           NaN             NaN         NaN      NaN     NaN
# 1960         NaN           NaN             NaN         NaN      NaN     NaN
# 1970        1.87           NaN            2.00         NaN     2.45    4.10
# 1980        3.00           NaN            3.50         NaN     5.04    3.20
# 1990        1.82           NaN            2.14        1.50     2.67    1.59
# 2000        1.29          1.50            2.00        2.67     1.35    1.90
# 2010        1.50          1.17            0.67        1.12     1.28    0.89
# 2020        0.62          0.29            0.40        0.11     0.32    0.39
#
#        Ecchi   Erotica   Fantasy   Girls Love  ...  Hentai  Horror  Mystery  \
# 1920     NaN       NaN       NaN          NaN  ...     NaN     NaN      NaN
# 1930     NaN       NaN      0.00          NaN  ...     NaN     NaN      NaN
# 1940     NaN       NaN       NaN          NaN  ...     NaN     NaN      NaN
# 1950     NaN       NaN      2.00          NaN  ...     NaN     NaN      NaN
# 1960     NaN       NaN      7.50          NaN  ...     NaN     NaN      NaN
# 1970    0.00       NaN      2.20          NaN  ...     NaN    0.00     4.00
# 1980     NaN       NaN      4.30          NaN  ...   22.00     NaN     1.00
# 1990    4.00       NaN      2.55          NaN  ...    3.73    2.46     2.25
# 2000    2.60      2.33      1.76         3.38  ...    5.29    1.00     4.56
# 2010    1.62      1.36      2.06         1.37  ...    1.11    1.81     1.39
# 2020    0.15      0.26      0.56         0.24  ...    0.33    0.28     0.67
#
#       Romance  Sci-Fi  Slice of Life  Sports  Supernatural  Suspense  UNKNOWN
# 1920      NaN     NaN            NaN     NaN           NaN       NaN     0.60
# 1930      NaN     NaN            NaN     NaN           NaN       NaN     5.00
# 1940      NaN     NaN           0.00    0.00           NaN       NaN     0.33
# 1950      NaN     NaN            NaN     NaN           NaN       NaN     0.60
# 1960      NaN     NaN            NaN     NaN          0.00       NaN    10.00
# 1970      NaN    3.00           0.17    6.00           NaN       NaN     2.50
# 1980    10.00    1.50          12.00    2.25          1.50       NaN     1.84
# 1990     1.55    1.61           1.25    1.04          3.00       NaN     1.52
# 2000     1.16    2.62           2.67    1.79          1.89       NaN     1.70
# 2010     3.67    2.03           8.38    3.30          4.47       1.0     4.00
# 2020     0.42    0.35           0.43    0.39          0.37       1.5     0.61
#
# [11 rows x 42 columns]

# %%
col_max = crescimento.max().idxmax()
idx_max = crescimento[col_max].idxmax()

crescimento.loc[[idx_max], [col_max]]
# Out:
#       Hentai
# 1980    22.0

# %%
plt.figure(figsize=(18,10))
sns.heatmap(crescimento, cmap='Blues', annot=True, linewidths=1)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 27. Agrupe os animes em clusters usando suas notas (“Score”) e número de membros (“Members”). Existe algum padrão entre os clusters identificados e os tipos de anime (“Type”)?

# %%
df = dados[['Type','Members','Score']]
df
# Out:
#         Type  Members    Score
# 0         TV  1771505     8.75
# 1      Movie   360978     8.38
# 2         TV   727252     8.22
# 3         TV   111931     7.25
# 4         TV    15001     6.94
# ...      ...      ...      ...
# 24900    ONA        0  UNKNOWN
# 24901    ONA        0  UNKNOWN
# 24902    ONA        0  UNKNOWN
# 24903  Music        0  UNKNOWN
# 24904  Music        0  UNKNOWN
#
# [24905 rows x 3 columns]

# %%
df['Score'] = pd.to_numeric(df['Score'],errors='coerce')
df = df.dropna()
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_10760\3306201912.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Score'] = pd.to_numeric(df['Score'],errors='coerce')

# %%
df
# Out:
#           Type  Members  Score
# 0           TV  1771505   8.75
# 1        Movie   360978   8.38
# 2           TV   727252   8.22
# 3           TV   111931   7.25
# 4           TV    15001   6.94
# ...        ...      ...    ...
# 24590      ONA      518   5.99
# 24635    Music      333   6.45
# 24729  Special      482   6.07
# 24831  Special      593   6.29
# 24856    Music      512   6.45
#
# [15692 rows x 3 columns]

# %%
tipos = df['Type'].unique()
tipos
# Out:
# ['TV', 'Movie', 'OVA', 'Special', 'ONA', 'Music', 'UNKNOWN']
# Categories (7, object): ['Movie', 'Music', 'ONA', 'OVA', 'Special', 'TV', 'UNKNOWN']

# %%
plt.figure(figsize=(18,8))


for t in tipos:
    tipado = df[df['Type'] == t]
    plt.scatter(x= tipado['Score'], 
                y= tipado['Members'], 
                label=t)

plt.legend()
plt.show()
